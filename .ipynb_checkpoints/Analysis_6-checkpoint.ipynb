# %% [markdown]
# ### Analysis 6
# + Comparison of Total graduated and Total employed in each major

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
df1=pd.read_csv('~/Final/Data/grad-students.csv')
df1.head()
# Out:
#    Major_code                                   Major  \
# 0        5601                   CONSTRUCTION SERVICES
# 1        6004       COMMERCIAL ART AND GRAPHIC DESIGN
# 2        6211                  HOSPITALITY MANAGEMENT
# 3        2201  COSMETOLOGY SERVICES AND CULINARY ARTS
# 4        2001              COMMUNICATION TECHNOLOGIES
#
#                         Major_category  Grad_total  Grad_sample_size  \
# 0  Industrial Arts & Consumer Services        9173               200
# 1                                 Arts       53864               882
# 2                             Business       24417               437
# 3  Industrial Arts & Consumer Services        5411                72
# 4              Computers & Mathematics        9109               171
#
#    Grad_employed  Grad_full_time_year_round  Grad_unemployed  \
# 0           7098                       6511              681
# 1          40492                      29553             2482
# ...

# %%
major=list(df1.groupby(by=['Major_category'])['Major_category'].unique())

# %%
grad_total=list(df1.groupby(by=['Major_category'])['Grad_total'].sum())

# %%
df2=pd.DataFrame({'Major_Graduated':major,'Total Graduated':grad_total})

# %%
df2=df2.sort_values(by=['Total Graduated'],ascending=[False])
df2
# Out:
#                           Major_Graduated  Total Graduated
# 6                             [Education]          3945300
# 9             [Humanities & Liberal Arts]          2825975
# 3                              [Business]          2718897
# 7                           [Engineering]          2132524
# 15                       [Social Science]          1839710
# 2                [Biology & Life Science]          1656556
# 14             [Psychology & Social Work]          1630545
# 8                                [Health]          1468337
# 13                    [Physical Sciences]          1052485
# 5               [Computers & Mathematics]           919817
# 1                                  [Arts]           580416
# 4           [Communications & Journalism]           462880
# 10  [Industrial Arts & Consumer Services]           317219
# 12                  [Law & Public Policy]           280852
# 0       [Agriculture & Natural Resources]           241342
# ...

# %%
gradEmployed=list(df1.groupby(by=['Major_category'])['Grad_employed'].sum())

# %%
df3=pd.DataFrame({'Major_Employed':major,'Total Employed':gradEmployed})
df3=df3.sort_values(by=['Total Employed'],ascending=[False])
df3
# Out:
#                            Major_Employed  Total Employed
# 6                             [Education]         2437166
# 3                              [Business]         2124495
# 9             [Humanities & Liberal Arts]         1986572
# 7                           [Engineering]         1634563
# 15                       [Social Science]         1381570
# 2                [Biology & Life Science]         1365336
# 14             [Psychology & Social Work]         1255928
# 8                                [Health]         1148800
# 13                    [Physical Sciences]          770365
# 5               [Computers & Mathematics]          716607
# 1                                  [Arts]          422450
# 4           [Communications & Journalism]          368390
# 10  [Industrial Arts & Consumer Services]          239338
# 12                  [Law & Public Policy]          224832
# 0       [Agriculture & Natural Resources]          179287
# ...

# %%
df4=pd.merge(df2, df3, right_index=True, left_index=True)
df4.to_csv('TotalGraduatedVsTotalEmployed.csv', encoding='utf-8')
